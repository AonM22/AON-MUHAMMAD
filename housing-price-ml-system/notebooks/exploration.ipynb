# %% [markdown]
# # Islamabad Housing Data Exploration
#
# Quick profiling notebook for the housing-price-ml-system project.

# %%
import pandas as pd
df = pd.read_csv('../data/Islamabad houses.csv')
df.head()

# %%
df.info()

# %%
df.describe(include='all').T.head(20)
